# %%
# Can you make a dataframe from a file you have uploaded and imported on your own
# Let's find out. Go to https://www.census.gov/support/ USACdataDownloads.html and download one of the Excel datafiles
# at the bottom of the page. Now, try to import that data into Python.

# %%
import pandas as pd
landarea = "datasets\datasets\landarea.xls"
df = pd.read_excel(landarea)

# %%
df.head()
# Out:
#         Areaname  STCOU  LND010190F  LND010190D  LND010190N1  LND010190N2  \
# 0  UNITED STATES      0           0  3787425.08            0            0
# 1        ALABAMA   1000           0    52422.94            0            0
# 2    Autauga, AL   1001           0      604.49            0            0
# 3    Baldwin, AL   1003           0     2027.08            0            0
# 4    Barbour, AL   1005           0      904.59            0            0
#
#    LND010200F  LND010200D  LND010200N1  LND010200N2  ...  LND110210N1  \
# 0           0  3794083.06            0            0  ...            0
# 1           0    52419.02            0            0  ...            0
# 2           0      604.45            0            0  ...            0
# 3           0     2026.93            0            0  ...            0
# 4           0      904.52            0            0  ...            0
#
#    LND110210N2  LND210190F  LND210190D  LND210190N1  LND210190N2  LND210200F  \
# ...
